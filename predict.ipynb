# %%
data = [
    [-0.7541830079917924, 0.5780143566720919, 0.11375998165198585, -0.14673040749854463, 0.0, 0.0, 0.0, 0.0, 2.0, 0.0, 2.0],
    [-0.5605884106597949, 0.753908347743766, 0.7003528882054108, 1.6923927520037099, 0.0, 1.0, 0.0, 1.0, 9.0, 1.0, 1.0],
    [0.11699268000219652, -0.3221490094005933, 0.5222180917013974, -0.8721429873346316, 1.0, 1.0, 0.0, 1.0, 5.0, 0.0, 2.0],
    [0.6977764719981892, -0.7256705183297281, -1.2170740485175422, 0.07677206232885857, 0.0, 0.0, 1.0, 1.0, 1.0, 0.0, 2.0]
]

# %%
import mlflow
logged_model = 'models:/Best_model_f1score'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(model_uri=logged_model)

# Predict on a Pandas DataFrame.
import pandas as pd
loaded_model.predict(pd.DataFrame(data))
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[2], line 5
#       2 logged_model = 'models:/Best_model_f1score'
#       4 # Load model as a PyFuncModel.
# ----> 5 loaded_model = mlflow.pyfunc.load_model(model_uri=logged_model)
#       7 # Predict on a Pandas DataFrame.
#       8 import pandas as pd
#
# File c:\Users\Mahmoud\anaconda3\envs\mlflow_env\Lib\site-packages\mlflow\tracing\provider.py:251, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     249 disable()
#     250 try:
# --> 251     return f(*args, **kwargs)
#     252 finally:
#     253     enable()
#
# File c:\Users\Mahmoud\anaconda3\envs\mlflow_env\Lib\site-packages\mlflow\pyfunc\__init__.py:979, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#     975         entity_list.append(Entity(job=job_entity))
# ...

# %%
import mlflow
logged_model = 'runs:/24c2565769db433db39c816a621035da/RandomForestClassifier/with-SMOTE'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# Predict on a Pandas DataFrame.
import pandas as pd
loaded_model.predict(pd.DataFrame(data))
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[3], line 5
#       2 logged_model = 'runs:/24c2565769db433db39c816a621035da/RandomForestClassifier/with-SMOTE'
#       4 # Load model as a PyFuncModel.
# ----> 5 loaded_model = mlflow.pyfunc.load_model(logged_model)
#       7 # Predict on a Pandas DataFrame.
#       8 import pandas as pd
#
# File c:\Users\Mahmoud\anaconda3\envs\mlflow_env\Lib\site-packages\mlflow\tracing\provider.py:251, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     249 disable()
#     250 try:
# --> 251     return f(*args, **kwargs)
#     252 finally:
#     253     enable()
#
# File c:\Users\Mahmoud\anaconda3\envs\mlflow_env\Lib\site-packages\mlflow\pyfunc\__init__.py:979, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#     975         entity_list.append(Entity(job=job_entity))
# ...
